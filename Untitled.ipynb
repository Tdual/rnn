# %%
import requests
import pandas as pd

df_list = []
for i in range(1, 21):
    data = {
        "page": i,
        "per_page":100,
        "sort":"count"
    }
    r = requests.get("http://qiita.com/api/v2/tags", params=data)
    if r.status_code != 200:
        print(r.text)
    r_df = pd.read_json(r.text)
    df_list.append(r_df)

df = pd.concat(df_list)
df
# Out:
#     followers_count                                           icon_url  \
# 0             17743  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 1             30279  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 2             16438  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 3             13196  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 4             19287  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 5              9094  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 6             19095  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 7              4769  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 8             18770  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 9             14685  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 10             2194  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 11            15764  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 12            12223  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 13            10753  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 14             2500  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 15            11622  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 16            10218  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 17            12053  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 18             8347  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 19             8413  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 20             2047  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 21            11083  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 22            20351  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 23              622  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 24             2135  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 25             1271  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 26             6903  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 27            13195  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 28            24193  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 29            14373  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# ..              ...                                                ...
# 70                1                                               None
# 71                0                                               None
# 72                7                                               None
# 73               13                                               None
# 74                1                                               None
# 75                6                                               None
# 76               20  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 77                5                                               None
# 78               10                                               None
# 79               11  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 80                3                                               None
# 81                3                                               None
# 82                9                                               None
# 83                2                                               None
# 84                1                                               None
# 85                7                                               None
# 86                3                                               None
# 87                1                                               None
# 88                0                                               None
# 89               10                                               None
# 90               14                                               None
# 91               52  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 92                1                                               None
# 93                0                                               None
# 94                1                                               None
# 95                2                                               None
# 96                2                                               None
# 97                6  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 98                0                                               None
# 99               28  https://s3-ap-northeast-1.amazonaws.com/qiita-...
#
#               id  items_count
# 0           Ruby        12523
# 1     JavaScript        12357
# 2         Python         8890
# 3            iOS         8547
# 4            PHP         8233
# 5          Rails         8056
# 6        Android         6963
# 7          Swift         6333
# 8           Java         6007
# 9          Linux         5199
# 10           AWS         5132
# 11           Git         4422
# 12           Mac         4043
# 13       Node.js         3860
# 14        docker         3804
# 15   Objective-C         3549
# 16         Xcode         3250
# 17         MySQL         3019
# 18            C#         2936
# 19        CentOS         2842
# 20         Unity         2824
# 21           C++         2706
# 22           CSS         2685
# 23       Windows         2665
# 24            Go         2611
# 25       vagrant         2517
# 26        Ubuntu         2357
# 27           Vim         2203
# 28          HTML         2131
# 29        jQuery         2130
# ..           ...          ...
# 70     julialang           21
# 71        report           21
# 72        Guzzle           21
# 73        Flyway           21
# 74     exception           21
# 75            分析           21
# 76      indesign           21
# 77       rsyslog           21
# 78        DBUnit           21
# 79     enthumble           21
# 80      optional           21
# 81     RadStudio           21
# 82            勉強           21
# 83          File           21
# 84            2D           21
# 85   Webアプリケーション           21
# 86          仮想環境           21
# 87            継承           21
# 88           RDP           21
# 89      ネットワーク分析           21
# 90        ライフハック           21
# 91        Pebble           21
# 92         やってみた           21
# 93          ログイン           21
# 94           ブログ           21
# 95        camera           21
# 96     CentOS6.4           21
# 97  FlashBuilder           21
# 98          サンプル           21
# 99         Boxen           21
#
# [2000 rows x 4 columns]

# %%
df.to_json("tags.json",orient="records")

# %%
import pandas as pd
df = pd.read_json("tags.json")
df.head()
# Out:
#    followers_count                                           icon_url  \
# 0            17743  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 1            30279  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 2            16438  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 3            13196  https://s3-ap-northeast-1.amazonaws.com/qiita-...
# 4            19287  https://s3-ap-northeast-1.amazonaws.com/qiita-...
#
#            id  items_count
# 0        Ruby        12523
# 1  JavaScript        12357
# 2      Python         8890
# 3         iOS         8547
# 4         PHP         8233

# %%
def get_tag(index, df):
    return df.ix[index,"id"]

get_tag(2,df)
# Out:
# 'Python'

# %%
df.ix[:,"items_count"].sum()
# Out:
# 380004

# %%
df.ix[:,"id"].tolist()
# Out:
# ['Ruby',
#  'JavaScript',
#  'Python',
#  'iOS',
#  'PHP',
#  'Rails',
#  'Android',
#  'Swift',
#  'Java',
#  'Linux',
#  'AWS',
#  'Git',
#  'Mac',
#  'Node.js',
#  'docker',
#  'Objective-C',
#  'Xcode',
#  'MySQL',
#  'C#',
#  'CentOS',
#  'Unity',
#  'C++',
#  'CSS',
#  'Windows',
#  'Go',
#  'vagrant',
#  'Ubuntu',
#  'Vim',
#  'HTML',
#  'jQuery',
#  'GitHub',
#  'Bash',
#  'Scala',
#  'MacOSX',
#  'RaspberryPi',
#  '機械学習',
#  'iPhone',
#  'R',
#  'ShellScript',
#  'Emacs',
#  'WordPress',
#  'HTML5',
#  'nginx',
#  'Haskell',
#  'golang',
#  'Heroku',
#  'AngularJS',
#  'Apache',
#  'Ansible',
#  'OSX',
#  'C',
#  'laravel',
#  'Perl',
#  'PostgreSQL',
#  'Slack',
#  'VirtualBox',
#  'SSH',
#  'Rails4',
#  'reactjs',
#  'CoffeeScript',
#  '初心者',
#  'Qiita',
#  'Zsh',
#  'AndroidStudio',
#  'homebrew',
#  'python3',
#  'chef',
#  'IoT',
#  'CakePHP',
#  'DeepLearning',
#  'Chrome',
#  'EC2',
#  'Elixir',
#  'AdventCalendar',
#  'TypeScript',
#  'SQL',
#  'Arduino',
#  'ATOM',
#  'Eclipse',
#  'Jenkins',
#  'shell',
#  'RSpec',
#  'CSS3',
#  'lambda',
#  'MongoDB',
#  'gulp',
#  'centos7',
#  '新人プログラマ応援',
#  'Twitter',
#  'Excel',
#  'PowerShell',
#  'MachineLearning',
#  'RubyOnRails',
#  'どう書く',
#  'JSON',
#  'TechEnglish',
#  'Elasticsearch',
#  'TensorFlow',
#  'api',
#  'aws-cli',
#  'Gem',
#  'Django',
#  'Azure',
#  'cocos2d-x',
#  'OpenCV',
#  'npm',
#  'S3',
#  'Markdown',
#  'Unity3D',
#  'VisualStudio',
#  'oracle',
#  'bootstrap',
#  'fluentd',
#  'gradle',
#  'Clojure',
#  'Redmine',
#  'Hubot',
#  'React',
#  'Sass',
#  'Xamarin',
#  'Bluemix',
#  'IntelliJ',
#  'cppBuilder',
#  'Redis',
#  'GoogleAppsScript',
#  'FuelPHP',
#  'ポエム',
#  'GoogleCloudPlatform',
#  '数学',
#  'memo',
#  'Groovy',
#  'Facebook',
#  'Electron',
#  'PlayFramework',
#  'spring',
#  'yhpg',
#  'Windows10',
#  'Web',
#  '.NET',
#  'UNIX',
#  'Erlang',
#  'Selenium',
#  'rbenv',
#  'VBA',
#  'Debian',
#  'GitLab',
#  'アルゴリズム',
#  'Kotlin',
#  'spring-boot',
#  'tmux',
#  'SoftLayer',
#  'WebGL',
#  'Terminal',
#  'es6',
#  'vmware',
#  'SublimeText',
#  'webpack',
#  'zabbix',
#  '正規表現',
#  'google',
#  'Network',
#  '自然言語処理',
#  'python2.7',
#  'SSL',
#  'セキュリティ',
#  'grunt',
#  'ESP8266',
#  'Spark',
#  'Titanium',
#  'hadoop',
#  'CocoaPods',
#  'Express',
#  'Pepper',
#  'windows7',
#  'redux',
#  '勉強会',
#  'プログラミング',
#  'capistrano',
#  'rust',
#  '電子工作',
#  'raspbian',
#  'ActiveRecord',
#  'メモ',
#  'Salesforce',
#  'C++11',
#  'java8',
#  'Chainer',
#  'SublimeText2',
#  'tips',
#  'C言語',
#  'link',
#  'laravel5',
#  'Security',
#  'TeX',
#  'LaTeX',
#  '画像処理',
#  'firefox',
#  'Sinatra',
#  'docker-compose',
#  'Maven',
#  'SublimeText3',
#  'Cordova',
#  'ImageMagick',
#  'pandas',
#  'CircleCI',
#  'Jupyter',
#  'vue.js',
#  'openstack',
#  'HTTP',
#  'GoogleAnalytics',
#  'UI',
#  'babel',
#  'cakephp3',
#  'SQLServer',
#  'デザインパターン',
#  'numpy',
#  'openssl',
#  'Backbone.js',
#  'CoreOS',
#  'dlang',
#  'processing',
#  'Firebase',
#  'archLinux',
#  'test',
#  'Angular2',
#  '統計学',
#  'devise',
#  'PHPUnit',
#  'GAE',
#  'オブジェクト指向',
#  'openFrameworks',
#  'Swift3.0',
#  'Lua',
#  'VisualStudioCode',
#  'android開発',
#  'mecab',
#  'Composer',
#  'ズンドコキヨシ',
#  'CSV',
#  'Ubuntu14.04',
#  'nodejs',
#  'iOS8',
#  'matplotlib',
#  'AppleScript',
#  'APIGateway',
#  'bigquery',
#  'CentOS6.x',
#  'Phoenix',
#  'mruby',
#  'UE4',
#  '入門',
#  'three.js',
#  'PhpStorm',
#  'statistics',
#  'ActionScript',
#  'Realm',
#  'WPF',
#  'node-red',
#  'bundler',
#  'Dart',
#  'Yum',
#  'ASP.NET',
#  'Xcode6',
#  'iOS9',
#  'dns',
#  '環境構築',
#  '開発環境',
#  'Ajax',
#  'ffmpeg',
#  'FreeBSD',
#  'mariadb',
#  'テスト',
#  'Tomcat',
#  'd3.js',
#  'command',
#  '人工知能',
#  'TravisCI',
#  'Cocoa',
#  'curl',
#  'flash',
#  'RDS',
#  'bot',
#  'Cygwin',
#  'NLP',
#  'データ分析',
#  'Capybara',
#  'js',
#  'Linuxコマンド',
#  'OpenGL',
#  'Subversion',
#  'Swift2.0',
#  'chrome-extension',
#  'websocket',
#  'CI',
#  'AmazonLinux',
#  'ElasticBeanstalk',
#  'scss',
#  'common-lisp',
#  'Yosemite',
#  'canvas',
#  'linebot',
#  'BLE',
#  'IAM',
#  'kubernetes',
#  'mqtt',
#  '備忘録',
#  'groonga',
#  'MyUnity',
#  'ESP-WROOM-02',
#  'SQLite3',
#  'bitbucket',
#  'XML',
#  'Bitcoin',
#  'GoogleAppEngine',
#  'bat',
#  'Qt',
#  'kintone',
#  'DynamoDB',
#  'Symfony2',
#  'Underscore.js',
#  'awk',
#  'GoogleMapsAPI',
#  'cron',
#  'postfix',
#  'SVG',
#  'browserify',
#  'Peco',
#  'DB',
#  'serverspec',
#  'FPGA',
#  'bluetooth',
#  'コマンドプロンプト',
#  'Haxe',
#  'Safari',
#  'スクレイピング',
#  'JUnit',
#  'GCC',
#  'XCode7',
#  'Database',
#  'Line',
#  'WebAPI',
#  '関数型プログラミング',
#  'math',
#  'scikit-learn',
#  'コマンド',
#  'Terraform',
#  'OAuth',
#  'TDD',
#  'kernel',
#  'photoshop',
#  'PhantomJS',
#  'vimrc',
#  'VR',
#  'Phalcon',
#  'TwitterAPI',
#  'TreasureData',
#  'シェルスクリプト',
#  'sbt',
#  'Storyboard',
#  'cloud9',
#  'FileMaker',
#  'IE',
#  'VB.Net',
#  'ROS',
#  'bower',
#  'RubyMotion',
#  'Compass',
#  'PHP7',
#  'Edison',
#  'IDCFクラウド',
#  'react.js',
#  'kibana',
#  'yeoman',
#  'Parse',
#  'borgWarp',
#  'mBaas',
#  'SourceTree',
#  'lisp',
#  'PDF',
#  'svn',
#  'borgSensorSystem1',
#  'Kobito',
#  'Xcode8',
#  'reactnative',
#  'CUDA',
#  '関数型言語',
#  'sed',
#  'debug',
#  'elcapitan',
#  'Conoha',
#  'proxy',
#  'Julia',
#  'RubyMine',
#  'serverless',
#  'iTerm2',
#  'F#',
#  'Scheme',
#  'VSCode',
#  'difference',
#  'es2015',
#  'Embulk',
#  'milkcocoa',
#  'Socket.io',
#  'ubuntu16.04',
#  'rubygems',
#  'docker-machine',
#  'RxJava',
#  'pyenv',
#  'brew',
#  'LINQ',
#  'game',
#  'AdventCalendar2016',
#  'JavaEE',
#  'Node',
#  'macos',
#  'Meteor',
#  '深層学習',
#  '設計',
#  'GLSL',
#  'Flask',
#  'tmlib.js',
#  'さくらVPS',
#  'CloudWatch',
#  'gmail',
#  'CloudFront',
#  'Jade',
#  'elb',
#  'Rails5',
#  'Watson',
#  'testing',
#  'pip',
#  'unicorn',
#  'riot',
#  'knockoutjs',
#  'flux',
#  'Blender',
#  'Play',
#  'ydnjp',
#  'IPython',
#  'vps',
#  'slim',
#  'ionic',
#  'jq',
#  'crystal',
#  'GIS',
#  '3D',
#  'analytics',
#  'KVM',
#  'PayPal',
#  'EC-CUBE3',
#  'gcp',
#  'monaca',
#  'ゲーム制作',
#  'gas',
#  'rest',
#  'GoogleSpreadSheet',
#  'systemd',
#  'HTTPS',
#  '翻訳',
#  'PhoneGap',
#  'stringOperation',
#  'angular',
#  'VPN',
#  'データベース',
#  '数値計算',
#  'cli',
#  'Nokogiri',
#  'CentOS6',
#  '最適化',
#  'fabric',
#  'apple',
#  'ExcelVBA',
#  'Design',
#  'solr',
#  'CodeIgniter',
#  'letsencrypt',
#  'RxSwift',
#  'WebRTC',
#  'zybo',
#  'twilio',
#  'mocha',
#  'VBScript',
#  'Raspberrypi3',
#  'RStudio',
#  'CloudFormation',
#  'YouTube',
#  'redshift',
#  'newrelic',
#  'MovableType',
#  'matlab',
#  'SpriteKit',
#  'Drupal',
#  'boost',
#  'リファクタリング',
#  'Rx',
#  'Choregraphe',
#  'ディープラーニング',
#  'wercker',
#  'vpc',
#  'boot2docker',
#  'VisualStudio2015',
#  'Windows8.1',
#  'Ethereum',
#  'OpenStreetMap',
#  'rake',
#  'font',
#  'FizzBuzz',
#  'ios10',
#  'AutoLayout',
#  'ターミナル',
#  'AIR',
#  'itamae',
#  'Unity2D',
#  '脆弱性',
#  'hive',
#  'Blockchain',
#  'swift3',
#  'NCMB',
#  'バッチファイル',
#  'proxmox',
#  'route53',
#  'chatwork',
#  'CMake',
#  'sqlite',
#  'pry',
#  'NAOqi',
#  'RuboCop',
#  'ネットワーク',
#  'middleman',
#  'YAML',
#  'Sphinx',
#  'grep',
#  'インストール',
#  'mail',
#  'Xamarin.Forms',
#  'フロントエンド',
#  'ProjectEuler',
#  'アプリ',
#  'xampp',
#  'promise',
#  'データ可視化',
#  'GitBucket',
#  'chef-solo',
#  'mbed',
#  'WebStorm',
#  'CoreData',
#  'uGUI',
#  'unity5',
#  'Mackerel',
#  'activeadmin',
#  'algorithm',
#  'Anaconda',
#  'ESLint',
#  'DataVisualization',
#  'Cisco',
#  'JavaFX',
#  'アジャイル',
#  'haml',
#  'ClojureScript',
#  'adamTaylor',
#  'MaterialDesign',
#  'minecraft',
#  'googlecomputeengine',
#  'さくらのクラウド',
#  'infrastructure',
#  'Puppet',
#  'iptables',
#  'rails3',
#  'CMS',
#  'Dropbox',
#  'Live2D',
#  'RxJS',
#  'Shader',
#  'Oculus',
#  'packer',
#  'ReactiveExtensions',
#  'Makefile',
#  'sh',
#  'NetBeans',
#  'server',
#  'OCaml',
#  'DDD',
#  'mamp',
#  'scipy',
#  'Grails',
#  'ASP.NET_MVC',
#  'ライブラリ',
#  'karma',
#  'Berkshelf',
#  'nosql',
#  'ARM',
#  'performance',
#  'lxc',
#  'Yii',
#  'less',
#  'myLineMonitor',
#  'OSS',
#  'iBeacon',
#  'English',
#  'unicode',
#  'Akka',
#  'ECMAScript',
#  'fedora',
#  'log',
#  'clang',
#  'BashOnUbuntuOnWindows',
#  'Kinesis',
#  '英語',
#  'rvm',
#  'Jekyll',
#  'ShinobiLayer',
#  'http2',
#  'bioinformatics',
#  'まとめ',
#  'Mojolicious',
#  'bookmarklet',
#  'illustrator',
#  'エディタ',
#  'googleapi',
#  'php-fpm',
#  'GPU',
#  'Microsoft',
#  'SORACOM',
#  'batch',
#  'XOOPS',
#  'Caffe',
#  'aws-sdk',
#  'paiza',
#  'Swift2',
#  'SSL証明書',
#  'WindowsServer',
#  'rpm',
#  'ios7',
#  '文字コード',
#  'devops',
#  'jasmine',
#  'error',
#  'Mithril.js',
#  'UniRx',
#  'vvvv',
#  'WatchKit',
#  '学習',
#  'emacs-lisp',
#  'SEO',
#  'redhat',
#  'Pandoc',
#  'めざせライブラリマスター',
#  'onsenui',
#  'chocolatey',
#  'CreateJS',
#  'Windows8',
#  'Delphi',
#  'SpringBoot',
#  'Karabiner',
#  'BaaS',
#  'Memcached',
#  'プログラミング教育',
#  'Elm',
#  'Push通知',
#  'unittest',
#  'enchant.js',
#  'animation',
#  'rsync',
#  '移行応援',
#  '言語処理100本ノック',
#  'SNS',
#  'インフラ',
#  'シェル芸',
#  '形態素解析',
#  'MVVM',
#  'mvc',
#  'httpd',
#  'RSS',
#  'RHEL',
#  'editor',
#  'Ruboty',
#  'selenium-webdriver',
#  'ニューラルネットワーク',
#  'Polymer',
#  'サーバー構築',
#  'GoogleDrive',
#  'サーバー',
#  'samba',
#  'AD2',
#  'エンジニア',
#  '画像認識',
#  'WebAudioAPI',
#  'carrierwave',
#  'Play2',
#  'Smarty',
#  'fileIO',
#  'zynq',
#  'msys2',
#  'DockerHub',
#  'td-agent',
#  'riak',
#  'UWP',
#  'gpio',
#  '競技プログラミング',
#  'iTunesConnect',
#  'ネタ',
#  'WiFi',
#  'Mercurial',
#  'iPad',
#  'myThings',
#  'カンファレンス・勉強会メモ',
#  '.NETFramework',
#  '時系列解析',
#  'appium',
#  'Smalltalk',
#  'Perl6',
#  'rack',
#  'Amazon',
#  'UX',
#  'Sierra',
#  'RPGツクールMV',
#  'glassfish',
#  'gnuplot',
#  'hipchat',
#  'PRML',
#  'ftp',
#  'stylus',
#  'JSP',
#  'JSX',
#  'Plugin',
#  'install',
#  'AdventCalendar2015',
#  'Datadog',
#  'purescript',
#  'ワンライナー',
#  'UITableView',
#  'cakephp2',
#  'Genymotion',
#  'UIKit',
#  'ツール',
#  'jira',
#  'ショートカット',
#  'エラー',
#  'Octopress',
#  'PDO',
#  'screen',
#  'Prolog',
#  'コミュニケーション',
#  'AI',
#  'Xaml',
#  'codeiq',
#  'SMTP',
#  'OpenSSH',
#  'Symfony',
#  'Sails.js',
#  'ESXi',
#  'spreadsheet',
#  'ifttt',
#  'naming',
#  'consul',
#  'EMR',
#  'FirefoxOS',
#  'virtualenv',
#  'concrete5',
#  'アニメーション',
#  'Cloud',
#  'I18n',
#  'webView',
#  'raspberrypi2',
#  'VMware_ESXi',
#  'WRF',
#  'SPA',
#  'Hyper-V',
#  'CTF',
#  'PostGIS',
#  '初心者向け',
#  'SendGrid',
#  'github-pages',
#  'lamp',
#  'RabbitMQ',
#  'NVIDIA',
#  'ゲーム',
#  'GUI',
#  'AMP',
#  'Lightning',
#  'ChatOps',
#  'ownCloud',
#  'AndroidWear',
#  'awscli',
#  'swagger',
#  'Siv3D',
#  'homebrew-cask',
#  'MIDI',
#  'Keyboard',
#  'emoji',
#  'JRuby',
#  'phpMyadmin',
#  'Fortran',
#  'trap',
#  'UnrealEngine',
#  'C++14',
#  'マネジメント',
#  'プロジェクト管理',
#  'adb',
#  'Ember.js',
#  'ドットインストール',
#  'FactoryGirl',
#  'fish',
#  'fastlane',
#  'Carthage',
#  'cocos2d-JS',
#  'Trello',
#  'CentOS6.5',
#  'teraterm',
#  'opendata',
#  '配列',
#  'Apex',
#  'programming',
#  'jpa',
#  'Graphviz',
#  'VyOS',
#  'Scratch',
#  'Thymeleaf',
#  '監視',
#  'FacebookSDK',
#  'ブラウザ',
#  'agile',
#  'Evernote',
#  'さくらのVPS',
#  '要望',
#  'AutoHotkey',
#  'Coq',
#  'vSphere',
#  'sketch',
#  'クラウド',
#  'word2vec',
#  'AWS_SDK',
#  'Asset',
#  'grunt.js',
#  'mroonga',
#  'OmniAuth',
#  'EntityFramework',
#  'cognito',
#  'VHDL',
#  'Sensu',
#  'Theta',
#  'scraping',
#  '小ネタ',
#  'Starling',
#  'neo4j',
#  'JScript',
#  'Flex',
#  'education',
#  'TLS',
#  'DigitalOcean',
#  'ntp',
#  'SeleniumIDE',
#  'struts2',
#  'cdn',
#  'bind',
#  'IDE',
#  'framework',
#  'adobe',
#  'passenger',
#  'dom',
#  'jquery.ui',
#  'Lチカ',
#  'I2C',
#  'ECS',
#  'FRP',
#  'phpenv',
#  'knife-solo',
#  'nodebrew',
#  'wget',
#  'QiitaAPI',
#  'pacemaker',
#  'macports',
#  'Padrino',
#  'riot.js',
#  '暗号',
#  'grafana',
#  'influxdb',
#  'diff',
#  'ses',
#  'deploy',
#  'RPi',
#  'dockerfile',
#  'mavericks',
#  'STL',
#  '強化学習',
#  'opsworks',
#  'LDAP',
#  'JMeter',
#  'cookie',
#  'tool',
#  'MinGW',
#  'Cucumber',
#  'Munin',
#  'watsoniotplatform',
#  'Keras',
#  'redash',
#  'Primer',
#  '可視化',
#  'InternetExplorer',
#  'AppStore',
#  'EC-CUBE',
#  '動画',
#  'bigdata',
#  'emmet',
#  'migration',
#  'Cognos',
#  'laravel5.2',
#  'Alloy',
#  'mono',
#  'sublime',
#  'SenchaTouch',
#  'Gauche',
#  'CommonLisp',
#  'alpine',
#  'watchOS',
#  'コーディング',
#  'IIS',
#  'デバッグ',
#  'バックアップ',
#  'bottle',
#  'USB',
#  'WebDriver',
#  'wiotp',
#  'borgCommSystem1',
#  'Alamofire',
#  'アプリ開発',
#  'スクラム',
#  'キーボード',
#  'Kafka',
#  '音声認識',
#  'ORM',
#  'Atlassian',
#  '自動化',
#  'Basic認証',
#  'AndroidSDK',
#  'datetime',
#  'sudo',
#  'template',
#  'ReVIEW',
#  'snippets',
#  'Gentoo',
#  'KVS',
#  'secureCoding',
#  'Hugo',
#  'h2o',
#  'microservices',
#  'gce',
#  'find',
#  'Revel',
#  'Cassandra',
#  'PowerPoint',
#  'Alfred',
#  'Verilog',
#  '.NETCore',
#  'CodeDeploy',
#  'REST-API',
#  'ipython_notebook',
#  'maya',
#  'libGDX',
#  'FontAwesome',
#  'nfs',
#  'wp-cli',
#  'DesignPatterns',
#  '基礎',
#  'BeagleBoneBlack',
#  'LeapMotion',
#  'コーディング規約',
#  'Brackets',
#  'MyBatis',
#  'uml',
#  'ExtJS',
#  'jubatus',
#  'nvm',
#  'casperJs',
#  'grape',
#  'RMagick',
#  'Mobile',
#  'mysql5.7',
#  'tvOS',
#  '運用',
#  'アセンブラ',
#  'Vagrantfile',
#  'チーム開発',
#  'AutoScaling',
#  'baserCMS',
#  'LibreOffice',
#  'adMob',
#  'mysqldump',
#  'Automator',
#  'Make',
#  'コマンドライン',
#  'org-mode',
#  'Octave',
#  'db2',
#  'backlog',
#  'cloudfoundry',
#  'デザイン',
#  'ant',
#  'jXA',
#  '資格',
#  ...]

# %%
one_hot = pd.get_dummies(df.ix[:,"id"].tolist())
one_hot.ix[:,"Ruby"]
one_hot.ix[:,"Ruby"].shape
# Out:
# (2000,)

# %%
import boto3
dynamodb = boto3.resource('dynamodb')

# %%
table = dynamodb.Table('qiita')

table.creation_date_time
# Out:
# datetime.datetime(2017, 1, 4, 20, 36, 21, 823000, tzinfo=tzlocal())

# %%
table.put_item(
    Item={
        "key1": "1",
        "index": "1"
   }
)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#    'content-length': '2',
#    'content-type': 'application/x-amz-json-1.0',
#    'date': 'Wed, 04 Jan 2017 12:02:08 GMT',
#    'server': 'Server',
#    'x-amz-crc32': '2745614147',
#    'x-amzn-requestid': 'BNHQ5RJO2HTPK8L5TI6VGQICVNVV4KQNSO5AEMVJF66Q9ASUAAJG'},
#   'HTTPStatusCode': 200,
#   'RequestId': 'BNHQ5RJO2HTPK8L5TI6VGQICVNVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'RetryAttempts': 0}}

# %%
import requests
body_url = "https://qiita.com/api/v1/tags/Python/items"
data = {
        "page": 1,
        "per_page":100,
        "sort":"count"
    }
r = requests.get(body_url, data)
if r.status_code != 200:
    print(r.text)
r.json()[0]
# Out:
# {'body': '\n<h1>\n<span id="分割ダウンロード" class="fragment"></span><a href="#%E5%88%86%E5%89%B2%E3%83%80%E3%82%A6%E3%83%B3%E3%83%AD%E3%83%BC%E3%83%89"><i class="fa fa-link"></i></a>分割ダウンロード</h1>\n\n<p>単純にダウンロードするととっても遅い（#^ω^）<br>\nそこでhttpリクエストヘッダーにRangeを付与し、データの何バイト目から何バイト目まで頂戴って送る</p>\n\n<div class="code-frame" data-lang="text"><div class="highlight"><pre>\nこのような感じ\nRange: bytes=0-999\n</pre></div></div>\n\n<p>詳しくは<a href="https://triple-underscore.github.io/RFC7233-ja.html#header.range" rel="nofollow noopener" target="_blank">RFC 7233 日本語訳</a></p>\n\n<h2>\n<span id="サンプルソースコード" class="fragment"></span><a href="#%E3%82%B5%E3%83%B3%E3%83%97%E3%83%AB%E3%82%BD%E3%83%BC%E3%82%B9%E3%82%B3%E3%83%BC%E3%83%89"><i class="fa fa-link"></i></a>サンプルソースコード</h2>\n\n<p>書きなぐりのコードなので各位リファクタリング</p>\n\n<div class="code-frame" data-lang="py"><div class="highlight"><pre>\n<span class="c"># /bin/env python</span>\n<span class="c"># -*- coding: utf-8 -*-</span>\n<span class="kn">import</span> <span class="nn">requests</span>\n<span class="kn">import</span> <span class="nn">urllib2</span>\n<span class="kn">from</span> <span class="nn">glob</span> <span class="kn">import</span> <span class="n">glob</span>\n<span class="kn">import</span> <span class="nn">os</span>\n\n<span class="c">#分割したファイルを結合</span>\n<span class="k">def</span> <span class="nf">combine</span><span class="p">(</span><span class="n">file_type</span><span class="p">,</span> <span class="n">file_name</span><span class="o">=</span><span class="s">"out"</span><span class="p">):</span>\n    <span class="k">with</span> <span class="nb">open</span><span class="p">(</span><span class="s">"</span><span class="si">%s</span><span class="s">.</span><span class="si">%s</span><span class="s">"</span> <span class="o">%</span> <span class="p">(</span><span class="n">file_name</span><span class="p">,</span> <span class="n">file_type</span><span class="p">),</span> <span class="s">"wb"</span><span class="p">)</span> <span class="k">as</span> <span class="nb">file</span><span class="p">:</span>\n        <span class="k">for</span> <span class="n">tmp_file</span> <span class="ow">in</span> <span class="n">glob</span><span class="p">(</span><span class="s">"*.tmp"</span><span class="p">):</span>\n            <span class="n">ftmp</span> <span class="o">=</span> <span class="nb">open</span><span class="p">(</span><span class="n">tmp_file</span><span class="p">,</span> <span class="s">"rb"</span><span class="p">)</span>\n            <span class="nb">file</span><span class="o">.</span><span class="n">write</span><span class="p">(</span><span class="n">ftmp</span><span class="o">.</span><span class="n">read</span><span class="p">())</span>\n            <span class="n">ftmp</span><span class="o">.</span><span class="n">close</span><span class="p">()</span>\n            <span class="n">os</span><span class="o">.</span><span class="n">remove</span><span class="p">(</span><span class="n">tmp_file</span><span class="p">)</span>\n\n<span class="c">#startからendまでダウンロード</span>\n<span class="k">def</span> <span class="nf">download</span><span class="p">(</span><span class="n">url</span><span class="p">,</span> <span class="n">num</span><span class="p">,</span> <span class="n">start</span><span class="p">,</span> <span class="n">end</span><span class="p">):</span>\n    <span class="n">req</span> <span class="o">=</span> <span class="n">urllib2</span><span class="o">.</span><span class="n">Request</span><span class="p">(</span><span class="n">url</span><span class="p">)</span>\n    <span class="n">req</span><span class="o">.</span><span class="n">headers</span><span class="p">[</span><span class="s">\'Range\'</span><span class="p">]</span> <span class="o">=</span> <span class="s">\'bytes=</span><span class="si">%s</span><span class="s">-</span><span class="si">%s</span><span class="s">\'</span> <span class="o">%</span> <span class="p">(</span><span class="n">start</span><span class="p">,</span> <span class="n">end</span><span cl ...
#  'comment_count': 0,
#  'created_at': '2017-01-04 20:04:07 +0900',
#  'created_at_as_seconds': 1483527847,
#  'created_at_in_words': '約1時間',
#  'gist_url': None,
#  'id': 457599,
#  'private': False,
#  'raw_body': '#分割ダウンロード\n単純にダウンロードするととっても遅い（#^ω^）\nそこでhttpリクエストヘッダーにRangeを付与し、データの何バイト目から何バイト目まで頂戴って送る\n\n```\nこのような感じ\nRange: bytes=0-999\n```\n\n詳しくは[RFC 7233 日本語訳](https://triple-underscore.github.io/RFC7233-ja.html#header.range)\n\n##サンプルソースコード\n書きなぐりのコードなので各位リファクタリング\n\n```py\n# /bin/env python\n# -*- coding: utf-8 -*-\nimport requests\nimport urllib2\nfrom glob import glob\nimport os\n\n#分割したファイルを結合\ndef combine(file_type, file_name="out"):\n    with open("%s.%s" % (file_name, file_type), "wb") as file:\n        for tmp_file in glob("*.tmp"):\n            ftmp = open(tmp_file, "rb")\n            file.write(ftmp.read())\n            ftmp.close()\n            os.remove(tmp_file)\n\n#startからendまでダウンロード\ndef download(url, num, start, end):\n    req = urllib2.Request(url)\n    req.headers[\'Range\'] = \'bytes=%s-%s\' % (start, end)\n    res = urllib2.urlopen(req)\n    with open("%s.tmp" % num, "wb") as file:\n        file.write(res.read())\n\n#分割ダウンロード\ndef split_download(url):\n    total_length = int(requests.head(url).headers.get("content-length", None))\n    file_type = requests.head(url).headers.get("content-type", None).split("/")[-1]\n    total_count = 0\n    last= 0\n    split_num = 10\n    for i, val in enumerate([(total_length + i) // split_num for i in range(split_num)]):\n        if i == 0:\n            last = val\n            download(url, i, 0, last)\n            total_count = val\n        else:\n            last = total_count + 1\n            total_count += val\n            download(url, i, last, total_count)\n    #結合\n    combine(file_type)\n\ndef main(url):\n    split_download(url)\n\nif __name__ == \'__main__\':\n    main(raw_input())\n```\n\n##ダウンロード時間の比較\n実験としてYoutubeの動画をダウンロードしてみる\n\nURL:[【MMD艦これ】プリンツ・オイゲンでLamb.【Prinz Eugen】「４Ｋ」\n](https://www.youtube.com/watch?v=ff8dFqmAU70)\nSize:61,531,848 バイト\n\n普通にダウンロード\n\n```py \nimport time\nimport requests\nimport urllib2\n\ndef download(url):\n    req = urllib2.Request(url)\n    res = urllib2.urlopen(req)\n    with open("out.mp4", "wb") as file:\n        file.write(res.read())\n\ndef main():\n    url = "http://r3---sn-p5qlsnz6.googlevideo.com/videoplayback?itag=22&ratebypass=yes&ip=159.253.144.86&upn=_QruIEPRuNQ&ipbits=0&pl=24&ei=F9JsWOr2M8Kg1gLPhLnIDQ&signature=928BE55DE4B8FCC2D0F92335978AE782BF18CE23.65FB2598D99464A91224B9F6F573EA0C18DDD420&source=youtube&mv=m&mt=1483526543&ms=au&mn=sn-p5qlsnz6&mm=31&id=o-AL7N7DYCdMwVgG-yDRHArP9OQXNWr-tGtHGfLUWujYuD&initcwndbps=4970000&key=yt6&mime=video%2Fmp4&sparams=dur%2Cei%2Cid%2Cinitcwndbps%2Cip%2Cipbits%2Citag%2Clmt%2Cmime%2Cmm%2Cmn%2Cms%2Cmv%2Cnh%2Cpl%2Cratebypass%2Csource%2Cupn%2Cexpire&expire=1483548279&nh=IgpwcjAzLmlhZDA3KgkxMjcuMC4wLjE&lmt=1471302962440452&dur=240.814&title=%E3%80%90MMD%E8%89%A6%E3%81%93%E3%82%8C%E3%80%91%E3%83%97%E3%83%AA%E3%83%B3%E3%83%84%E3%83%BB%E3%82%AA%E3%82%A4%E3%82%B2%E3%83%B3%E3%81%A7Lamb.%E3%80%90Prinz+Eugen%E3%80%91%E3%80%8C%EF%BC%94%EF%BC%AB%E3%80%8D"\n    start = time.time()\n    download(url)\n    elapsed_time = time.time() - start\n    print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"\n\nif __name__ == \'__main__\':\n    main()\n```\n\n\n\n\n分割ダウンロード\n\n```py\n\nimport requests\nimport urllib2\nfrom glob import glob\nimport os\nimport time\n\ndef download(url, num, start, end):\n    req = urllib2.Request(url)\n    req.headers[\'Range\'] = \'bytes=%s-%s\' % (start, end)\n    res = urllib2.urlopen(req)\n    with open("%s.tmp" % num, "wb") as file:\n        file.write(res.read())\n\ndef split_download(url):\n    total_length = int(requests.head(url).headers.get("content-length", None))\n    file_type = requests.head(url).headers.get("content-type", None).split("/")[-1]\n    total_count = 0\n    last= 0\n    split_num = 10\n    for i, val in enumerate([(total_length + i) // split_num for i in range(split_num)]):\n        if i == 0:\n            last = val\n            download(url, i, 0, last)\n            total_count = val\n        else:\n            last = total_count + 1\n       ...
#  'stock_count': 2,
#  'stock_users': ['zaoriku0', 'Tsutomu-KKE@github'],
#  'stocked': False,
#  'tags': [{'following': False,
#    'icon_url': 'https://s3-ap-northeast-1.amazonaws.com/qiita-tag-image/28fd3d6b220c89e6197fd82c02fd2fcd2bb66d81/medium.jpg?1383884245',
#    'name': 'Python',
#    'url_name': 'python',
#    'versions': []},
#   {'following': False,
#    'icon_url': 'https://s3-ap-northeast-1.amazonaws.com/qiita-tag-image/c2072a07d93a651c4066eed93f326b2e0914bde4/medium.jpg?1474583030',
#    'name': 'python2.7',
#    'url_name': 'python2.7',
#    'versions': []}],
#  'title': 'python で 分割ダウンロード',
#  'tweet': True,
#  'updated_at': '2017-01-04 20:11:05 +0900',
#  'updated_at_in_words': '約1時間',
#  'url': 'http://qiita.com/code_monkey/items/25e96431c3533d9cd35a',
#  'user': {'following': False,
#   'id': 122949,
#   'profile_image_url': 'https://qiita-image-store.s3.amazonaws.com/0/122949/profile-images/1473715402',
#   'url_name': 'code_monkey'},
#  'uuid': '25e96431c3533d9cd35a'}

# %%
# !rm -rf tmp/tensorflow_log/*

import tensorflow as tf
import numpy as np
import random


num_of_input_nodes = 1
num_of_hidden_nodes = 80
num_of_output_nodes = 1
num_of_training_epochs = 50000
batch_size = 100
num_of_prediction_epochs = 100
learning_rate = 0.001
forget_bias = 0.9
num_of_sample = 1000
num_layers = 1

batch_size = 100
sequences_length = num_predictors 
test_num = int(num_of_sample*0.3)
class_num = 2

def get_batch(batch_size, X, t):
    rnum = [random.randint(0, len(X) - 1) for x in range(batch_size)]
    xs = np.array([[[y] for y in list(X[r])] for r in rnum])
    ts = np.array([t[r] for r in rnum])
    return xs, ts


def create_batch(batch_size, X, t):
    X = X.as_matrix()
    t = t.as_matrix()
    rnum = [random.randint(0, len(X) - 1) for x in range(batch_size)]
    xs = np.array([[[y] for y in list(X[r])] for r in rnum])
    ts = np.array([t[r] for r in rnum])
    return xs, ts


def unpack_sequence(tensor):
    return tf.unpack(tf.transpose(tensor, perm=[1, 0, 2]))

def pack_sequence(sequence):
    return tf.transpose(tf.pack(sequence), perm=[1, 0, 2])

def inference(input_ph):
    with tf.name_scope("inference") as scope:
        in_size = num_of_hidden_nodes
        out_size = class_num
        weight = tf.Variable(tf.truncated_normal([in_size, out_size], stddev=0.1))
        bias = tf.Variable(tf.constant(0.1, shape=[out_size]))
        
       
        # network = tf.nn.rnn_cell.LSTMCell(num_of_hidden_nodes)
        network = tf.nn.rnn_cell.GRUCell(num_of_hidden_nodes)
        network = tf.nn.rnn_cell.DropoutWrapper(network, output_keep_prob=0.5)
        network = tf.nn.rnn_cell.MultiRNNCell([network] * num_layers)
        inputs =  unpack_sequence(input_ph)
        
        rnn_output, states_op = tf.nn.rnn(network,inputs,dtype=tf.float32)
        #rnn_output = pack_sequence(rnn_output)
        #state_op = pack_sequence(states_op)
        output_op = tf.nn.softmax(tf.matmul(rnn_output[-1], weight) + bias)

 
        tf.histogram_summary("weights", weight)
        tf.histogram_summary("biases", bias)
        tf.histogram_summary("output",  output_op)
        results = [weight, bias]
        return output_op, states_op, results


def loss(output_op, supervisor_ph):
    with tf.name_scope("loss") as scope:
        loss_op = - tf.reduce_sum(supervisor_ph * tf.log(output_op))
        tf.scalar_summary("loss", loss_op)
        return loss_op


def training(loss_op):
    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)
        return training_op

def accuracy(output_op, supervisor_ph):
    with tf.name_scope("accuracy") as scope:
        correct_prediction = tf.equal(tf.argmax(output_op,1), tf.argmax(supervisor_ph,1))
        accuracy_op = tf.reduce_mean(tf.cast(correct_prediction, "float"))
        tf.scalar_summary("accuracy", accuracy_op)
        return accuracy_op

def calc_accuracy(accuracy_opp, X, t):
    inputs, targets = create_batch(len(X), X, t)
    pred_dict = {
        input_ph:  inputs,
        supervisor_ph: targets
    }
    accurecy = sess.run(accuracy_op, feed_dict=pred_dict)
    print(accurecy)



random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)

#optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
optimizer = tf.train.AdadeltaOptimizer(learning_rate=learning_rate)

with tf.Graph().as_default():
    input_ph = tf.placeholder(tf.float32, [None, sequences_length, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, class_num], name="supervisor")

    output_op, states_op, datas_op = inference(input_ph)
    loss_op = loss(output_op, supervisor_ph)
    training_op = training(loss_op)
    accuracy_op = accuracy(output_op, supervisor_ph)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("tmp/tensorflow_log", graph=sess.graph)
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = create_batch(batch_size, training_predictors_tf , classes_tf[:training_set_size])
            train_dict = {
                input_ph:   inputs,
                supervisor_ph: supervisors
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch) % 1000 == 0:
                #summary_str, loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                loss = sess.run(loss_op, feed_dict=train_dict)
                print("train#{}, loss: {}".format(epoch, loss))
                #summary_writer.add_summary(summary_str, epoch)
                if (epoch) % 5000 == 0:
                    calc_accuracy(output_op, test_predictors_tf, test_classes_tf)
        calc_accuracy(output_op, X_test, t_test)
        datas = sess.run(datas_op)
        saver.save(sess, "model.ckpt")
# Out:
# ---------
# NameErrorTraceback (most recent call last)
# <ipython-input-1-3f32d111417a> in <module>()
#      18
#      19 batch_size = 100
# ---> 20 sequences_length = num_predictors
#      21 test_num = int(num_of_sample*0.3)
#      22 class_num = 2
#
# NameError: name 'num_predictors' is not defined
